# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# # Load data sets

# %%
climate_df = pd.read_csv('data/02-processed/climate_clean.csv')
coffee_df = pd.read_csv('data/02-processed/coffee_prices_clean.csv')

# %%
climate_df.head()
# Out:
#    year_month  brazil_temp_mean  brazil_precip_mean  vietnam_temp_mean  \
# 0  2009-01-01         24.496492            3.236261          21.152823
# 1  2009-02-01         24.680386            3.492561          25.691071
# 2  2009-03-01         24.709951            3.078186          25.988306
# 3  2009-04-01         23.333977            2.792995          27.182500
# 4  2009-05-01         21.934531            2.044548          26.795161
#
#    vietnam_precip_mean
# 0             1.788065
# 1             1.598750
# 2             3.845242
# 3             9.283667
# 4            11.564113

# %%
coffee_df.head()
# Out:
#          date     value
# 0  2009-01-01  1.165700
# 1  2009-02-01  1.140832
# 2  2009-03-01  1.116909
# 3  2009-04-01  1.159362
# 4  2009-05-01  1.297150

# %%
# Out:
# ('2009-01-01', '2026-01-01')
