# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
coffee_df = pd.read_csv('data/00-raw/coffee-prices-historical-data.csv')

# %%
coffee_df.head()
# Out:
#          date   value
# 0  1973-08-20  0.6735
# 1  1973-08-21  0.6710
# 2  1973-08-22  0.6580
# 3  1973-08-23  0.6675
# 4  1973-08-24  0.6660

# %%
coffee_df.isnull().sum()
# Out:
# date       0
#  value    21
# dtype: int64

# %% [markdown]
# # Drop null values

# %%
nonull_coffee_df = coffee_df.dropna()

# %%
nonull_coffee_df.isnull().sum()
# Out:
# date      0
#  value    0
# dtype: int64
